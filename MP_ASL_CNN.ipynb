# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, csv_file, batch_size=32, image_size=(400,400), shuffle=True):
        self.data = pd.read_csv(csv_file)
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()

        self.label_encoder = LabelEncoder()
        self.data['label'] = self.label_encoder.fit_transform(self.data['label'])

    def __len__(self):
        return len(self.data) // self.batch_size

    def __getitem__(self, index):
        batch_data = self.data.iloc[index * self.batch_size : (index + 1) * self.batch_size]
        X, y = self.__data_generation(batch_data)
        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            self.data = self.data.sample(frac=1).reset_index(drop=True)

    def __data_generation(self, batch_data):
        X = np.empty((self.batch_size, *self.image_size, 1))
        y = np.empty((self.batch_size), dtype=int)

        for i, row in enumerate(batch_data.iterrows()):
            img_path, label = row[1]['image_path'], row[1]['label']
            img = tf.keras.preprocessing.image.load_img(img_path, color_mode="grayscale", target_size=self.image_size)
            X[i,] = tf.keras.preprocessing.image.img_to_array(img) / 255.0
            y[i] = label

        return X, y

# %%
# !unzip processed_combine_asl_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: processed_combine_asl_dataset/y/Y1190.jpg
#   inflating: processed_combine_asl_dataset/y/Y1191.jpg
#   inflating: processed_combine_asl_dataset/y/Y1192.jpg
#   inflating: processed_combine_asl_dataset/y/Y1193.jpg
#   inflating: processed_combine_asl_dataset/y/Y1194.jpg
#   inflating: processed_combine_asl_dataset/y/Y1195.jpg
#   inflating: processed_combine_asl_dataset/y/Y1196.jpg
#   inflating: processed_combine_asl_dataset/y/Y1197.jpg
#   inflating: processed_combine_asl_dataset/y/Y1198.jpg
#   inflating: processed_combine_asl_dataset/y/Y1199.jpg
#   inflating: processed_combine_asl_dataset/y/Y12 - Copy - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y12.jpg
#   inflating: processed_combine_asl_dataset/y/Y120.jpg
#   inflating: processed_combine_asl_dataset/y/Y1200.jpg
#   inflating: processed_combine_asl_dataset/y/Y1201.jpg
#   inflating: processed_combine_asl_dataset/y/Y1202.jpg
#   inflating: processed_combine_asl_dataset/y/Y1203.jpg
#   inflating: processed_combine_asl_dataset/y/Y1204.jpg
#   inflating: processed_combine_asl_dataset/y/Y1205.jpg
#   inflating: processed_combine_asl_dataset/y/Y1206.jpg
#   inflating: processed_combine_asl_dataset/y/Y1207.jpg
#   inflating: processed_combine_asl_dataset/y/Y1208.jpg
#   inflating: processed_combine_asl_dataset/y/Y1209.jpg
#   inflating: processed_combine_asl_dataset/y/Y121.jpg
#   inflating: processed_combine_asl_dataset/y/Y1210.jpg
#   inflating: processed_combine_asl_dataset/y/Y1211.jpg
#   inflating: processed_combine_asl_dataset/y/Y1212.jpg
#   inflating: processed_combine_asl_dataset/y/Y1213.jpg
#   inflating: processed_combine_asl_dataset/y/Y1214.jpg
#   inflating: processed_combine_asl_dataset/y/Y1215.jpg
#   inflating: processed_combine_asl_dataset/y/Y1216.jpg
#   inflating: processed_combine_asl_dataset/y/Y1217.jpg
#   inflating: processed_combine_asl_dataset/y/Y1218.jpg
#   inflating: processed_combine_asl_dataset/y/Y1219.jpg
#   inflating: processed_combine_asl_dataset/y/Y122.jpg
#   inflating: processed_combine_asl_dataset/y/Y1220.jpg
#   inflating: processed_combine_asl_dataset/y/Y1221.jpg
#   inflating: processed_combine_asl_dataset/y/Y1222.jpg
#   inflating: processed_combine_asl_dataset/y/Y1223.jpg
#   inflating: processed_combine_asl_dataset/y/Y1224.jpg
#   inflating: processed_combine_asl_dataset/y/Y1225.jpg
#   inflating: processed_combine_asl_dataset/y/Y1226.jpg
#   inflating: processed_combine_asl_dataset/y/Y1227.jpg
#   inflating: processed_combine_asl_dataset/y/Y1228.jpg
#   inflating: processed_combine_asl_dataset/y/Y1229.jpg
#   inflating: processed_combine_asl_dataset/y/Y123.jpg
#   inflating: processed_combine_asl_dataset/y/Y1230.jpg
#   inflating: processed_combine_asl_dataset/y/Y1231.jpg
#   inflating: processed_combine_asl_dataset/y/Y1232.jpg
#   inflating: processed_combine_asl_dataset/y/Y1233.jpg
#   inflating: processed_combine_asl_dataset/y/Y1234.jpg
#   inflating: processed_combine_asl_dataset/y/Y1235.jpg
#   inflating: processed_combine_asl_dataset/y/Y1236.jpg
#   inflating: processed_combine_asl_dataset/y/Y1237.jpg
#   inflating: processed_combine_asl_dataset/y/Y1238.jpg
#   inflating: processed_combine_asl_dataset/y/Y1239.jpg
#   inflating: processed_combine_asl_dataset/y/Y124.jpg
#   inflating: processed_combine_asl_dataset/y/Y1240.jpg
#   inflating: processed_combine_asl_dataset/y/Y1241.jpg
#   inflating: processed_combine_asl_dataset/y/Y1242.jpg
#   inflating: processed_combine_asl_dataset/y/Y1243.jpg
#   inflating: processed_combine_asl_dataset/y/Y1244.jpg
#   inflating: processed_combine_asl_dataset/y/Y1245.jpg
#   inflating: processed_combine_asl_dataset/y/Y1246.jpg
#   inflating: processed_combine_asl_dataset/y/Y1247.jpg
#   inflating: processed_combine_asl_dataset/y/Y1248.jpg
#   inflating: processed_combine_asl_dataset/y/Y1249.jpg
#   inflating: processed_combine_asl_dataset/y/Y125.jpg
#   inflating: processed_combine_asl_dataset/y/Y1250.jpg
#   inflating: processed_combine_asl_dataset/y/Y1251.jpg
#   inflating: processed_combine_asl_dataset/y/Y1252.jpg
#   inflating: processed_combine_asl_dataset/y/Y1253.jpg
#   inflating: processed_combine_asl_dataset/y/Y1254.jpg
#   inflating: processed_combine_asl_dataset/y/Y1255.jpg
#   inflating: processed_combine_asl_dataset/y/Y1256.jpg
#   inflating: processed_combine_asl_dataset/y/Y1257.jpg
#   inflating: processed_combine_asl_dataset/y/Y1258.jpg
#   inflating: processed_combine_asl_dataset/y/Y1259.jpg
#   inflating: processed_combine_asl_dataset/y/Y126.jpg
#   inflating: processed_combine_asl_dataset/y/Y1260.jpg
#   inflating: processed_combine_asl_dataset/y/Y1261.jpg
#   inflating: processed_combine_asl_dataset/y/Y1262.jpg
#   inflating: processed_combine_asl_dataset/y/Y1263.jpg
#   inflating: processed_combine_asl_dataset/y/Y1264.jpg
#   inflating: processed_combine_asl_dataset/y/Y1265.jpg
#   inflating: processed_combine_asl_dataset/y/Y1266.jpg
#   inflating: processed_combine_asl_dataset/y/Y1267.jpg
#   inflating: processed_combine_asl_dataset/y/Y1268.jpg
#   inflating: processed_combine_asl_dataset/y/Y1269.jpg
#   inflating: processed_combine_asl_dataset/y/Y127.jpg
#   inflating: processed_combine_asl_dataset/y/Y1270.jpg
#   inflating: processed_combine_asl_dataset/y/Y1271.jpg
#   inflating: processed_combine_asl_dataset/y/Y1272.jpg
#   inflating: processed_combine_asl_dataset/y/Y1273.jpg
#   inflating: processed_combine_asl_dataset/y/Y1274.jpg
#   inflating: processed_combine_asl_dataset/y/Y1275.jpg
#   inflating: processed_combine_asl_dataset/y/Y1276.jpg
#   inflating: processed_combine_asl_dataset/y/Y1277.jpg
#   inflating: processed_combine_asl_dataset/y/Y1278.jpg
#   inflating: processed_combine_asl_dataset/y/Y1279.jpg
#   inflating: processed_combine_asl_dataset/y/Y128.jpg
#   inflating: processed_combine_asl_dataset/y/Y1280.jpg
#   inflating: processed_combine_asl_dataset/y/Y1281.jpg
#   inflating: processed_combine_asl_dataset/y/Y1282.jpg
#   inflating: processed_combine_asl_dataset/y/Y1283.jpg
#   inflating: processed_combine_asl_dataset/y/Y1284.jpg
#   inflating: processed_combine_asl_dataset/y/Y1285.jpg
#   inflating: processed_combine_asl_dataset/y/Y1286.jpg
#   inflating: processed_combine_asl_dataset/y/Y1287.jpg
#   inflating: processed_combine_asl_dataset/y/Y1288.jpg
#   inflating: processed_combine_asl_dataset/y/Y1289.jpg
#   inflating: processed_combine_asl_dataset/y/Y129 - Copy - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y129.jpg
#   inflating: processed_combine_asl_dataset/y/Y1290.jpg
#   inflating: processed_combine_asl_dataset/y/Y1291.jpg
#   inflating: processed_combine_asl_dataset/y/Y1292.jpg
#   inflating: processed_combine_asl_dataset/y/Y1293.jpg
#   inflating: processed_combine_asl_dataset/y/Y1294.jpg
#   inflating: processed_combine_asl_dataset/y/Y1295.jpg
#   inflating: processed_combine_asl_dataset/y/Y1296.jpg
#   inflating: processed_combine_asl_dataset/y/Y1297.jpg
#   inflating: processed_combine_asl_dataset/y/Y1298.jpg
#   inflating: processed_combine_asl_dataset/y/Y1299.jpg
#   inflating: processed_combine_asl_dataset/y/Y13.jpg
#   inflating: processed_combine_asl_dataset/y/Y130.jpg
#   inflating: processed_combine_asl_dataset/y/Y1300.jpg
#   inflating: processed_combine_asl_dataset/y/Y1301.jpg
#   inflating: processed_combine_asl_dataset/y/Y1302.jpg
#   inflating: processed_combine_asl_dataset/y/Y1303.jpg
#   inflating: processed_combine_asl_dataset/y/Y1304.jpg
#   inflating: processed_combine_asl_dataset/y/Y1305.jpg
#   inflating: processed_combine_asl_dataset/y/Y1306.jpg
#   inflating: processed_combine_asl_dataset/y/Y1307.jpg
#   inflating: processed_combine_asl_dataset/y/Y1308.jpg
#   inflating: processed_combine_asl_dataset/y/Y1309.jpg
#   inflating: processed_combine_asl_dataset/y/Y131.jpg
#   inflating: processed_combine_asl_dataset/y/Y1310.jpg
#   inflating: processed_combine_asl_dataset/y/Y1311.jpg
#   inflating: processed_combine_asl_dataset/y/Y1312.jpg
#   inflating: processed_combine_asl_dataset/y/Y1313.jpg
#   inflating: processed_combine_asl_dataset/y/Y1314.jpg
#   inflating: processed_combine_asl_dataset/y/Y1315.jpg
#   inflating: processed_combine_asl_dataset/y/Y1316.jpg
#   inflating: processed_combine_asl_dataset/y/Y1317.jpg
#   inflating: processed_combine_asl_dataset/y/Y1318.jpg
#   inflating: processed_combine_asl_dataset/y/Y1319.jpg
#   inflating: processed_combine_asl_dataset/y/Y132.jpg
#   inflating: processed_combine_asl_dataset/y/Y1320.jpg
#   inflating: processed_combine_asl_dataset/y/Y1321.jpg
#   inflating: processed_combine_asl_dataset/y/Y1322.jpg
#   inflating: processed_combine_asl_dataset/y/Y1323.jpg
#   inflating: processed_combine_asl_dataset/y/Y1324.jpg
#   inflating: processed_combine_asl_dataset/y/Y1325.jpg
#   inflating: processed_combine_asl_dataset/y/Y1326.jpg
#   inflating: processed_combine_asl_dataset/y/Y1327.jpg
#   inflating: processed_combine_asl_dataset/y/Y1328.jpg
#   inflating: processed_combine_asl_dataset/y/Y1329.jpg
#   inflating: processed_combine_asl_dataset/y/Y133.jpg
#   inflating: processed_combine_asl_dataset/y/Y1330.jpg
#   inflating: processed_combine_asl_dataset/y/Y1331.jpg
#   inflating: processed_combine_asl_dataset/y/Y1332.jpg
#   inflating: processed_combine_asl_dataset/y/Y1333.jpg
#   inflating: processed_combine_asl_dataset/y/Y1334.jpg
#   inflating: processed_combine_asl_dataset/y/Y1335.jpg
#   inflating: processed_combine_asl_dataset/y/Y1336.jpg
#   inflating: processed_combine_asl_dataset/y/Y1337.jpg
#   inflating: processed_combine_asl_dataset/y/Y1338.jpg
#   inflating: processed_combine_asl_dataset/y/Y1339.jpg
#   inflating: processed_combine_asl_dataset/y/Y134.jpg
#   inflating: processed_combine_asl_dataset/y/Y1340.jpg
#   inflating: processed_combine_asl_dataset/y/Y1341.jpg
#   inflating: processed_combine_asl_dataset/y/Y1342.jpg
#   inflating: processed_combine_asl_dataset/y/Y1343.jpg
#   inflating: processed_combine_asl_dataset/y/Y1344.jpg
#   inflating: processed_combine_asl_dataset/y/Y1345.jpg
#   inflating: processed_combine_asl_dataset/y/Y1346.jpg
#   inflating: processed_combine_asl_dataset/y/Y1347.jpg
#   inflating: processed_combine_asl_dataset/y/Y1348.jpg
#   inflating: processed_combine_asl_dataset/y/Y1349.jpg
#   inflating: processed_combine_asl_dataset/y/Y135.jpg
#   inflating: processed_combine_asl_dataset/y/Y1350.jpg
#   inflating: processed_combine_asl_dataset/y/Y1351.jpg
#   inflating: processed_combine_asl_dataset/y/Y1352.jpg
#   inflating: processed_combine_asl_dataset/y/Y1353.jpg
#   inflating: processed_combine_asl_dataset/y/Y1354.jpg
#   inflating: processed_combine_asl_dataset/y/Y1355.jpg
#   inflating: processed_combine_asl_dataset/y/Y1356.jpg
#   inflating: processed_combine_asl_dataset/y/Y1357.jpg
#   inflating: processed_combine_asl_dataset/y/Y1358.jpg
#   inflating: processed_combine_asl_dataset/y/Y1359.jpg
#   inflating: processed_combine_asl_dataset/y/Y136 - Copy - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y136.jpg
#   inflating: processed_combine_asl_dataset/y/Y1360.jpg
#   inflating: processed_combine_asl_dataset/y/Y1361.jpg
#   inflating: processed_combine_asl_dataset/y/Y1362.jpg
#   inflating: processed_combine_asl_dataset/y/Y1364.jpg
#   inflating: processed_combine_asl_dataset/y/Y1367.jpg
#   inflating: processed_combine_asl_dataset/y/Y1368.jpg
#   inflating: processed_combine_asl_dataset/y/Y1369.jpg
#   inflating: processed_combine_asl_dataset/y/Y137.jpg
#   inflating: processed_combine_asl_dataset/y/Y1370.jpg
#   inflating: processed_combine_asl_dataset/y/Y1371.jpg
#   inflating: processed_combine_asl_dataset/y/Y1373.jpg
#   inflating: processed_combine_asl_dataset/y/Y1375.jpg
#   inflating: processed_combine_asl_dataset/y/Y1376.jpg
#   inflating: processed_combine_asl_dataset/y/Y1377.jpg
#   inflating: processed_combine_asl_dataset/y/Y1378.jpg
#   inflating: processed_combine_asl_dataset/y/Y1379.jpg
#   inflating: processed_combine_asl_dataset/y/Y138.jpg
#   inflating: processed_combine_asl_dataset/y/Y1380.jpg
#   inflating: processed_combine_asl_dataset/y/Y1381.jpg
#   inflating: processed_combine_asl_dataset/y/Y1382.jpg
#   inflating: processed_combine_asl_dataset/y/Y1383.jpg
#   inflating: processed_combine_asl_dataset/y/Y1384.jpg
#   inflating: processed_combine_asl_dataset/y/Y1385.jpg
#   inflating: processed_combine_asl_dataset/y/Y1386.jpg
#   inflating: processed_combine_asl_dataset/y/Y1387.jpg
#   inflating: processed_combine_asl_dataset/y/Y1388.jpg
#   inflating: processed_combine_asl_dataset/y/Y1389.jpg
#   inflating: processed_combine_asl_dataset/y/Y139.jpg
#   inflating: processed_combine_asl_dataset/y/Y1390.jpg
#   inflating: processed_combine_asl_dataset/y/Y1391.jpg
#   inflating: processed_combine_asl_dataset/y/Y1392.jpg
#   inflating: processed_combine_asl_dataset/y/Y1393.jpg
#   inflating: processed_combine_asl_dataset/y/Y1394.jpg
#   inflating: processed_combine_asl_dataset/y/Y1395.jpg
#   inflating: processed_combine_asl_dataset/y/Y1396.jpg
#   inflating: processed_combine_asl_dataset/y/Y1397.jpg
#   inflating: processed_combine_asl_dataset/y/Y1398.jpg
#   inflating: processed_combine_asl_dataset/y/Y1399.jpg
#   inflating: processed_combine_asl_dataset/y/Y14.jpg
#   inflating: processed_combine_asl_dataset/y/Y140.jpg
#   inflating: processed_combine_asl_dataset/y/Y1400.jpg
#   inflating: processed_combine_asl_dataset/y/Y1401 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1401.jpg
#   inflating: processed_combine_asl_dataset/y/Y1402.jpg
#   inflating: processed_combine_asl_dataset/y/Y1403.jpg
#   inflating: processed_combine_asl_dataset/y/Y1404.jpg
#   inflating: processed_combine_asl_dataset/y/Y1405.jpg
#   inflating: processed_combine_asl_dataset/y/Y1406.jpg
#   inflating: processed_combine_asl_dataset/y/Y1407 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1407.jpg
#   inflating: processed_combine_asl_dataset/y/Y1408.jpg
#   inflating: processed_combine_asl_dataset/y/Y1409.jpg
#   inflating: processed_combine_asl_dataset/y/Y141.jpg
#   inflating: processed_combine_asl_dataset/y/Y1410.jpg
#   inflating: processed_combine_asl_dataset/y/Y1411.jpg
#   inflating: processed_combine_asl_dataset/y/Y1412.jpg
#   inflating: processed_combine_asl_dataset/y/Y1413 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1413.jpg
#   inflating: processed_combine_asl_dataset/y/Y1414.jpg
#   inflating: processed_combine_asl_dataset/y/Y1415.jpg
#   inflating: processed_combine_asl_dataset/y/Y1416.jpg
#   inflating: processed_combine_asl_dataset/y/Y1417.jpg
#   inflating: processed_combine_asl_dataset/y/Y1418.jpg
#   inflating: processed_combine_asl_dataset/y/Y1419.jpg
#   inflating: processed_combine_asl_dataset/y/Y142.jpg
#   inflating: processed_combine_asl_dataset/y/Y1420.jpg
#   inflating: processed_combine_asl_dataset/y/Y1421 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1421.jpg
#   inflating: processed_combine_asl_dataset/y/Y1422.jpg
#   inflating: processed_combine_asl_dataset/y/Y1423.jpg
#   inflating: processed_combine_asl_dataset/y/Y1424.jpg
#   inflating: processed_combine_asl_dataset/y/Y1425.jpg
#   inflating: processed_combine_asl_dataset/y/Y1426.jpg
#   inflating: processed_combine_asl_dataset/y/Y1427.jpg
#   inflating: processed_combine_asl_dataset/y/Y1428.jpg
#   inflating: processed_combine_asl_dataset/y/Y1429.jpg
#   inflating: processed_combine_asl_dataset/y/Y143.jpg
#   inflating: processed_combine_asl_dataset/y/Y1430.jpg
#   inflating: processed_combine_asl_dataset/y/Y1431.jpg
#   inflating: processed_combine_asl_dataset/y/Y1432.jpg
#   inflating: processed_combine_asl_dataset/y/Y1433.jpg
#   inflating: processed_combine_asl_dataset/y/Y1434.jpg
#   inflating: processed_combine_asl_dataset/y/Y1435.jpg
#   inflating: processed_combine_asl_dataset/y/Y1436.jpg
#   inflating: processed_combine_asl_dataset/y/Y1437.jpg
#   inflating: processed_combine_asl_dataset/y/Y1438.jpg
#   inflating: processed_combine_asl_dataset/y/Y1439.jpg
#   inflating: processed_combine_asl_dataset/y/Y144.jpg
#   inflating: processed_combine_asl_dataset/y/Y1440.jpg
#   inflating: processed_combine_asl_dataset/y/Y1441.jpg
#   inflating: processed_combine_asl_dataset/y/Y1442.jpg
#   inflating: processed_combine_asl_dataset/y/Y1443.jpg
#   inflating: processed_combine_asl_dataset/y/Y1444.jpg
#   inflating: processed_combine_asl_dataset/y/Y1445.jpg
#   inflating: processed_combine_asl_dataset/y/Y1446.jpg
#   inflating: processed_combine_asl_dataset/y/Y1447.jpg
#   inflating: processed_combine_asl_dataset/y/Y1448.jpg
#   inflating: processed_combine_asl_dataset/y/Y1449.jpg
#   inflating: processed_combine_asl_dataset/y/Y145.jpg
#   inflating: processed_combine_asl_dataset/y/Y1450.jpg
#   inflating: processed_combine_asl_dataset/y/Y1451.jpg
#   inflating: processed_combine_asl_dataset/y/Y1452.jpg
#   inflating: processed_combine_asl_dataset/y/Y1453 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1453.jpg
#   inflating: processed_combine_asl_dataset/y/Y1454.jpg
#   inflating: processed_combine_asl_dataset/y/Y1455.jpg
#   inflating: processed_combine_asl_dataset/y/Y1456.jpg
#   inflating: processed_combine_asl_dataset/y/Y1457.jpg
#   inflating: processed_combine_asl_dataset/y/Y1458.jpg
#   inflating: processed_combine_asl_dataset/y/Y1459.jpg
#   inflating: processed_combine_asl_dataset/y/Y146.jpg
#   inflating: processed_combine_asl_dataset/y/Y1460.jpg
#   inflating: processed_combine_asl_dataset/y/Y1461.jpg
#   inflating: processed_combine_asl_dataset/y/Y1462.jpg
#   inflating: processed_combine_asl_dataset/y/Y1463.jpg
#   inflating: processed_combine_asl_dataset/y/Y1464.jpg
#   inflating: processed_combine_asl_dataset/y/Y1465.jpg
#   inflating: processed_combine_asl_dataset/y/Y1466.jpg
#   inflating: processed_combine_asl_dataset/y/Y1467.jpg
#   inflating: processed_combine_asl_dataset/y/Y1468.jpg
#   inflating: processed_combine_asl_dataset/y/Y1469.jpg
#   inflating: processed_combine_asl_dataset/y/Y147.jpg
#   inflating: processed_combine_asl_dataset/y/Y1470.jpg
#   inflating: processed_combine_asl_dataset/y/Y1471.jpg
#   inflating: processed_combine_asl_dataset/y/Y1472.jpg
#   inflating: processed_combine_asl_dataset/y/Y1473.jpg
#   inflating: processed_combine_asl_dataset/y/Y1474.jpg
#   inflating: processed_combine_asl_dataset/y/Y1475.jpg
#   inflating: processed_combine_asl_dataset/y/Y1476.jpg
#   inflating: processed_combine_asl_dataset/y/Y1477.jpg
#   inflating: processed_combine_asl_dataset/y/Y1478.jpg
#   inflating: processed_combine_asl_dataset/y/Y1479.jpg
#   inflating: processed_combine_asl_dataset/y/Y148.jpg
#   inflating: processed_combine_asl_dataset/y/Y1480.jpg
#   inflating: processed_combine_asl_dataset/y/Y1481.jpg
#   inflating: processed_combine_asl_dataset/y/Y1482.jpg
#   inflating: processed_combine_asl_dataset/y/Y1483.jpg
#   inflating: processed_combine_asl_dataset/y/Y1484.jpg
#   inflating: processed_combine_asl_dataset/y/Y1485.jpg
#   inflating: processed_combine_asl_dataset/y/Y1486.jpg
#   inflating: processed_combine_asl_dataset/y/Y1487.jpg
#   inflating: processed_combine_asl_dataset/y/Y1488.jpg
#   inflating: processed_combine_asl_dataset/y/Y1489.jpg
#   inflating: processed_combine_asl_dataset/y/Y149.jpg
#   inflating: processed_combine_asl_dataset/y/Y1490.jpg
#   inflating: processed_combine_asl_dataset/y/Y1491.jpg
#   inflating: processed_combine_asl_dataset/y/Y1492.jpg
#   inflating: processed_combine_asl_dataset/y/Y1493.jpg
#   inflating: processed_combine_asl_dataset/y/Y1494.jpg
#   inflating: processed_combine_asl_dataset/y/Y1495.jpg
#   inflating: processed_combine_asl_dataset/y/Y1496.jpg
#   inflating: processed_combine_asl_dataset/y/Y1497.jpg
#   inflating: processed_combine_asl_dataset/y/Y1498.jpg
#   inflating: processed_combine_asl_dataset/y/Y1499.jpg
#   inflating: processed_combine_asl_dataset/y/Y15 - Copy - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y15.jpg
#   inflating: processed_combine_asl_dataset/y/Y150.jpg
#   inflating: processed_combine_asl_dataset/y/Y1500.jpg
#   inflating: processed_combine_asl_dataset/y/Y1501.jpg
#   inflating: processed_combine_asl_dataset/y/Y1502.jpg
#   inflating: processed_combine_asl_dataset/y/Y1503.jpg
#   inflating: processed_combine_asl_dataset/y/Y1504.jpg
#   inflating: processed_combine_asl_dataset/y/Y1505.jpg
#   inflating: processed_combine_asl_dataset/y/Y1506.jpg
#   inflating: processed_combine_asl_dataset/y/Y1507.jpg
#   inflating: processed_combine_asl_dataset/y/Y1508.jpg
#   inflating: processed_combine_asl_dataset/y/Y1509.jpg
#   inflating: processed_combine_asl_dataset/y/Y151.jpg
#   inflating: processed_combine_asl_dataset/y/Y1510.jpg
#   inflating: processed_combine_asl_dataset/y/Y1511.jpg
#   inflating: processed_combine_asl_dataset/y/Y1512.jpg
#   inflating: processed_combine_asl_dataset/y/Y1513.jpg
#   inflating: processed_combine_asl_dataset/y/Y1514.jpg
#   inflating: processed_combine_asl_dataset/y/Y1515.jpg
#   inflating: processed_combine_asl_dataset/y/Y1516.jpg
#   inflating: processed_combine_asl_dataset/y/Y1517.jpg
#   inflating: processed_combine_asl_dataset/y/Y1518.jpg
#   inflating: processed_combine_asl_dataset/y/Y1519.jpg
#   inflating: processed_combine_asl_dataset/y/Y152.jpg
#   inflating: processed_combine_asl_dataset/y/Y1520.jpg
#   inflating: processed_combine_asl_dataset/y/Y1521.jpg
#   inflating: processed_combine_asl_dataset/y/Y1522.jpg
#   inflating: processed_combine_asl_dataset/y/Y1523.jpg
#   inflating: processed_combine_asl_dataset/y/Y1524.jpg
#   inflating: processed_combine_asl_dataset/y/Y1525.jpg
#   inflating: processed_combine_asl_dataset/y/Y1526.jpg
#   inflating: processed_combine_asl_dataset/y/Y1527.jpg
#   inflating: processed_combine_asl_dataset/y/Y1528.jpg
#   inflating: processed_combine_asl_dataset/y/Y1529.jpg
#   inflating: processed_combine_asl_dataset/y/Y153.jpg
#   inflating: processed_combine_asl_dataset/y/Y1530.jpg
#   inflating: processed_combine_asl_dataset/y/Y1531.jpg
#   inflating: processed_combine_asl_dataset/y/Y1532.jpg
#   inflating: processed_combine_asl_dataset/y/Y1533.jpg
#   inflating: processed_combine_asl_dataset/y/Y1534.jpg
#   inflating: processed_combine_asl_dataset/y/Y1535.jpg
#   inflating: processed_combine_asl_dataset/y/Y1536.jpg
#   inflating: processed_combine_asl_dataset/y/Y1537.jpg
#   inflating: processed_combine_asl_dataset/y/Y1538.jpg
#   inflating: processed_combine_asl_dataset/y/Y1539 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1539.jpg
#   inflating: processed_combine_asl_dataset/y/Y154.jpg
#   inflating: processed_combine_asl_dataset/y/Y1540.jpg
#   inflating: processed_combine_asl_dataset/y/Y1541.jpg
#   inflating: processed_combine_asl_dataset/y/Y1542.jpg
#   inflating: processed_combine_asl_dataset/y/Y1543.jpg
#   inflating: processed_combine_asl_dataset/y/Y1544.jpg
#   inflating: processed_combine_asl_dataset/y/Y1545.jpg
#   inflating: processed_combine_asl_dataset/y/Y1546.jpg
#   inflating: processed_combine_asl_dataset/y/Y1547 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1547.jpg
#   inflating: processed_combine_asl_dataset/y/Y1548.jpg
#   inflating: processed_combine_asl_dataset/y/Y1549.jpg
#   inflating: processed_combine_asl_dataset/y/Y155.jpg
#   inflating: processed_combine_asl_dataset/y/Y1550.jpg
#   inflating: processed_combine_asl_dataset/y/Y1551.jpg
#   inflating: processed_combine_asl_dataset/y/Y1552.jpg
#   inflating: processed_combine_asl_dataset/y/Y1553.jpg
#   inflating: processed_combine_asl_dataset/y/Y1554.jpg
#   inflating: processed_combine_asl_dataset/y/Y1555 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1555.jpg
#   inflating: processed_combine_asl_dataset/y/Y1556.jpg
#   inflating: processed_combine_asl_dataset/y/Y1557.jpg
#   inflating: processed_combine_asl_dataset/y/Y1558.jpg
#   inflating: processed_combine_asl_dataset/y/Y1559.jpg
#   inflating: processed_combine_asl_dataset/y/Y156.jpg
#   inflating: processed_combine_asl_dataset/y/Y1560.jpg
#   inflating: processed_combine_asl_dataset/y/Y1561 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1561.jpg
#   inflating: processed_combine_asl_dataset/y/Y1562.jpg
#   inflating: processed_combine_asl_dataset/y/Y1563.jpg
#   inflating: processed_combine_asl_dataset/y/Y1564.jpg
#   inflating: processed_combine_asl_dataset/y/Y1565.jpg
#   inflating: processed_combine_asl_dataset/y/Y1566.jpg
#   inflating: processed_combine_asl_dataset/y/Y1567.jpg
#   inflating: processed_combine_asl_dataset/y/Y1568.jpg
#   inflating: processed_combine_asl_dataset/y/Y1569.jpg
#   inflating: processed_combine_asl_dataset/y/Y157.jpg
#   inflating: processed_combine_asl_dataset/y/Y1570.jpg
#   inflating: processed_combine_asl_dataset/y/Y1571.jpg
#   inflating: processed_combine_asl_dataset/y/Y1572.jpg
#   inflating: processed_combine_asl_dataset/y/Y1573.jpg
#   inflating: processed_combine_asl_dataset/y/Y1574.jpg
#   inflating: processed_combine_asl_dataset/y/Y1575.jpg
#   inflating: processed_combine_asl_dataset/y/Y1576.jpg
#   inflating: processed_combine_asl_dataset/y/Y1577.jpg
#   inflating: processed_combine_asl_dataset/y/Y1578.jpg
#   inflating: processed_combine_asl_dataset/y/Y1579 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1579.jpg
#   inflating: processed_combine_asl_dataset/y/Y158.jpg
#   inflating: processed_combine_asl_dataset/y/Y1580.jpg
#   inflating: processed_combine_asl_dataset/y/Y1581.jpg
#   inflating: processed_combine_asl_dataset/y/Y1582.jpg
#   inflating: processed_combine_asl_dataset/y/Y1583.jpg
#   inflating: processed_combine_asl_dataset/y/Y1584.jpg
#   inflating: processed_combine_asl_dataset/y/Y1585.jpg
#   inflating: processed_combine_asl_dataset/y/Y1586.jpg
#   inflating: processed_combine_asl_dataset/y/Y1587.jpg
#   inflating: processed_combine_asl_dataset/y/Y1588.jpg
#   inflating: processed_combine_asl_dataset/y/Y1589.jpg
#   inflating: processed_combine_asl_dataset/y/Y159.jpg
#   inflating: processed_combine_asl_dataset/y/Y1590.jpg
#   inflating: processed_combine_asl_dataset/y/Y1591.jpg
#   inflating: processed_combine_asl_dataset/y/Y1592.jpg
#   inflating: processed_combine_asl_dataset/y/Y1593.jpg
#   inflating: processed_combine_asl_dataset/y/Y1594.jpg
#   inflating: processed_combine_asl_dataset/y/Y1595.jpg
#   inflating: processed_combine_asl_dataset/y/Y1596.jpg
#   inflating: processed_combine_asl_dataset/y/Y1597.jpg
#   inflating: processed_combine_asl_dataset/y/Y1598.jpg
#   inflating: processed_combine_asl_dataset/y/Y1599.jpg
#   inflating: processed_combine_asl_dataset/y/Y16.jpg
#   inflating: processed_combine_asl_dataset/y/Y160.jpg
#   inflating: processed_combine_asl_dataset/y/Y1600.jpg
#   inflating: processed_combine_asl_dataset/y/Y1601.jpg
#   inflating: processed_combine_asl_dataset/y/Y1602.jpg
#   inflating: processed_combine_asl_dataset/y/Y1603.jpg
#   inflating: processed_combine_asl_dataset/y/Y1604.jpg
#   inflating: processed_combine_asl_dataset/y/Y1605.jpg
#   inflating: processed_combine_asl_dataset/y/Y1606.jpg
#   inflating: processed_combine_asl_dataset/y/Y1607.jpg
#   inflating: processed_combine_asl_dataset/y/Y1608.jpg
#   inflating: processed_combine_asl_dataset/y/Y1609.jpg
#   inflating: processed_combine_asl_dataset/y/Y161.jpg
#   inflating: processed_combine_asl_dataset/y/Y1610.jpg
#   inflating: processed_combine_asl_dataset/y/Y1611.jpg
#   inflating: processed_combine_asl_dataset/y/Y1612.jpg
#   inflating: processed_combine_asl_dataset/y/Y1613.jpg
#   inflating: processed_combine_asl_dataset/y/Y1614.jpg
#   inflating: processed_combine_asl_dataset/y/Y1615.jpg
#   inflating: processed_combine_asl_dataset/y/Y1616.jpg
#   inflating: processed_combine_asl_dataset/y/Y1617.jpg
#   inflating: processed_combine_asl_dataset/y/Y1618.jpg
#   inflating: processed_combine_asl_dataset/y/Y1619.jpg
#   inflating: processed_combine_asl_dataset/y/Y162.jpg
#   inflating: processed_combine_asl_dataset/y/Y1620.jpg
#   inflating: processed_combine_asl_dataset/y/Y1621.jpg
#   inflating: processed_combine_asl_dataset/y/Y1622.jpg
#   inflating: processed_combine_asl_dataset/y/Y1623.jpg
#   inflating: processed_combine_asl_dataset/y/Y1624.jpg
#   inflating: processed_combine_asl_dataset/y/Y1625.jpg
#   inflating: processed_combine_asl_dataset/y/Y1626.jpg
#   inflating: processed_combine_asl_dataset/y/Y1627.jpg
#   inflating: processed_combine_asl_dataset/y/Y1628.jpg
#   inflating: processed_combine_asl_dataset/y/Y1629.jpg
#   inflating: processed_combine_asl_dataset/y/Y163.jpg
#   inflating: processed_combine_asl_dataset/y/Y1630.jpg
#   inflating: processed_combine_asl_dataset/y/Y1631.jpg
#   inflating: processed_combine_asl_dataset/y/Y1632.jpg
#   inflating: processed_combine_asl_dataset/y/Y1633.jpg
#   inflating: processed_combine_asl_dataset/y/Y1634.jpg
#   inflating: processed_combine_asl_dataset/y/Y1635.jpg
#   inflating: processed_combine_asl_dataset/y/Y1636.jpg
#   inflating: processed_combine_asl_dataset/y/Y1637.jpg
#   inflating: processed_combine_asl_dataset/y/Y1638.jpg
#   inflating: processed_combine_asl_dataset/y/Y1639.jpg
#   inflating: processed_combine_asl_dataset/y/Y164.jpg
#   inflating: processed_combine_asl_dataset/y/Y1640.jpg
#   inflating: processed_combine_asl_dataset/y/Y1641.jpg
#   inflating: processed_combine_asl_dataset/y/Y1642.jpg
#   inflating: processed_combine_asl_dataset/y/Y1643.jpg
#   inflating: processed_combine_asl_dataset/y/Y1644.jpg
#   inflating: processed_combine_asl_dataset/y/Y1645.jpg
#   inflating: processed_combine_asl_dataset/y/Y1646.jpg
#   inflating: processed_combine_asl_dataset/y/Y1647.jpg
#   inflating: processed_combine_asl_dataset/y/Y1648.jpg
#   inflating: processed_combine_asl_dataset/y/Y1649.jpg
#   inflating: processed_combine_asl_dataset/y/Y165.jpg
#   inflating: processed_combine_asl_dataset/y/Y1650.jpg
#   inflating: processed_combine_asl_dataset/y/Y1651.jpg
#   inflating: processed_combine_asl_dataset/y/Y1652.jpg
#   inflating: processed_combine_asl_dataset/y/Y1653.jpg
#   inflating: processed_combine_asl_dataset/y/Y1654.jpg
#   inflating: processed_combine_asl_dataset/y/Y1655.jpg
#   inflating: processed_combine_asl_dataset/y/Y1656.jpg
#   inflating: processed_combine_asl_dataset/y/Y1657.jpg
#   inflating: processed_combine_asl_dataset/y/Y1658.jpg
#   inflating: processed_combine_asl_dataset/y/Y1659.jpg
#   inflating: processed_combine_asl_dataset/y/Y166.jpg
#   inflating: processed_combine_asl_dataset/y/Y1660.jpg
#   inflating: processed_combine_asl_dataset/y/Y1661.jpg
#   inflating: processed_combine_asl_dataset/y/Y1662.jpg
#   inflating: processed_combine_asl_dataset/y/Y1663.jpg
#   inflating: processed_combine_asl_dataset/y/Y1664.jpg
#   inflating: processed_combine_asl_dataset/y/Y1665.jpg
#   inflating: processed_combine_asl_dataset/y/Y1666 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1666.jpg
#   inflating: processed_combine_asl_dataset/y/Y1667.jpg
#   inflating: processed_combine_asl_dataset/y/Y1668.jpg
#   inflating: processed_combine_asl_dataset/y/Y1669.jpg
#   inflating: processed_combine_asl_dataset/y/Y167.jpg
#   inflating: processed_combine_asl_dataset/y/Y1670.jpg
#   inflating: processed_combine_asl_dataset/y/Y1671 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1671.jpg
#   inflating: processed_combine_asl_dataset/y/Y1672.jpg
#   inflating: processed_combine_asl_dataset/y/Y1673.jpg
#   inflating: processed_combine_asl_dataset/y/Y1674.jpg
#   inflating: processed_combine_asl_dataset/y/Y1675.jpg
#   inflating: processed_combine_asl_dataset/y/Y1676.jpg
#   inflating: processed_combine_asl_dataset/y/Y1677.jpg
#   inflating: processed_combine_asl_dataset/y/Y1678.jpg
#   inflating: processed_combine_asl_dataset/y/Y1679.jpg
#   inflating: processed_combine_asl_dataset/y/Y168.jpg
#   inflating: processed_combine_asl_dataset/y/Y1680.jpg
#   inflating: processed_combine_asl_dataset/y/Y1681 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1681.jpg
#   inflating: processed_combine_asl_dataset/y/Y1682.jpg
#   inflating: processed_combine_asl_dataset/y/Y1683.jpg
#   inflating: processed_combine_asl_dataset/y/Y1684.jpg
#   inflating: processed_combine_asl_dataset/y/Y1685.jpg
#   inflating: processed_combine_asl_dataset/y/Y1686.jpg
#   inflating: processed_combine_asl_dataset/y/Y1687.jpg
#   inflating: processed_combine_asl_dataset/y/Y1688.jpg
#   inflating: processed_combine_asl_dataset/y/Y1689.jpg
#   inflating: processed_combine_asl_dataset/y/Y169.jpg
#   inflating: processed_combine_asl_dataset/y/Y1690.jpg
#   inflating: processed_combine_asl_dataset/y/Y1691.jpg
#   inflating: processed_combine_asl_dataset/y/Y1692.jpg
#   inflating: processed_combine_asl_dataset/y/Y1693.jpg
#   inflating: processed_combine_asl_dataset/y/Y1694.jpg
#   inflating: processed_combine_asl_dataset/y/Y1695.jpg
#   inflating: processed_combine_asl_dataset/y/Y1696.jpg
#   inflating: processed_combine_asl_dataset/y/Y1697.jpg
#   inflating: processed_combine_asl_dataset/y/Y1698.jpg
#   inflating: processed_combine_asl_dataset/y/Y1699.jpg
#   inflating: processed_combine_asl_dataset/y/Y17 - Copy - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y17.jpg
#   inflating: processed_combine_asl_dataset/y/Y170.jpg
#   inflating: processed_combine_asl_dataset/y/Y1700.jpg
#   inflating: processed_combine_asl_dataset/y/Y1701.jpg
#   inflating: processed_combine_asl_dataset/y/Y1702.jpg
#   inflating: processed_combine_asl_dataset/y/Y1703.jpg
#   inflating: processed_combine_asl_dataset/y/Y1704.jpg
#   inflating: processed_combine_asl_dataset/y/Y1705.jpg
#   inflating: processed_combine_asl_dataset/y/Y1706.jpg
#   inflating: processed_combine_asl_dataset/y/Y1707.jpg
#   inflating: processed_combine_asl_dataset/y/Y1708.jpg
#   inflating: processed_combine_asl_dataset/y/Y1709.jpg
#   inflating: processed_combine_asl_dataset/y/Y171.jpg
#   inflating: processed_combine_asl_dataset/y/Y1710.jpg
#   inflating: processed_combine_asl_dataset/y/Y1711.jpg
#   inflating: processed_combine_asl_dataset/y/Y1712.jpg
#   inflating: processed_combine_asl_dataset/y/Y1713.jpg
#   inflating: processed_combine_asl_dataset/y/Y1714.jpg
#   inflating: processed_combine_asl_dataset/y/Y1715.jpg
#   inflating: processed_combine_asl_dataset/y/Y1716.jpg
#   inflating: processed_combine_asl_dataset/y/Y1717.jpg
#   inflating: processed_combine_asl_dataset/y/Y1718.jpg
#   inflating: processed_combine_asl_dataset/y/Y1719.jpg
#   inflating: processed_combine_asl_dataset/y/Y172.jpg
#   inflating: processed_combine_asl_dataset/y/Y1720.jpg
#   inflating: processed_combine_asl_dataset/y/Y1721.jpg
#   inflating: processed_combine_asl_dataset/y/Y1722.jpg
#   inflating: processed_combine_asl_dataset/y/Y1723.jpg
#   inflating: processed_combine_asl_dataset/y/Y1724.jpg
#   inflating: processed_combine_asl_dataset/y/Y1725.jpg
#   inflating: processed_combine_asl_dataset/y/Y1726.jpg
#   inflating: processed_combine_asl_dataset/y/Y1727.jpg
#   inflating: processed_combine_asl_dataset/y/Y1728.jpg
#   inflating: processed_combine_asl_dataset/y/Y1729.jpg
#   inflating: processed_combine_asl_dataset/y/Y173.jpg
#   inflating: processed_combine_asl_dataset/y/Y1730.jpg
#   inflating: processed_combine_asl_dataset/y/Y1731.jpg
#   inflating: processed_combine_asl_dataset/y/Y1732.jpg
#   inflating: processed_combine_asl_dataset/y/Y1733.jpg
#   inflating: processed_combine_asl_dataset/y/Y1734.jpg
#   inflating: processed_combine_asl_dataset/y/Y1735.jpg
#   inflating: processed_combine_asl_dataset/y/Y1736.jpg
#   inflating: processed_combine_asl_dataset/y/Y1737.jpg
#   inflating: processed_combine_asl_dataset/y/Y1738.jpg
#   inflating: processed_combine_asl_dataset/y/Y1739.jpg
#   inflating: processed_combine_asl_dataset/y/Y174.jpg
#   inflating: processed_combine_asl_dataset/y/Y1740.jpg
#   inflating: processed_combine_asl_dataset/y/Y1741.jpg
#   inflating: processed_combine_asl_dataset/y/Y1742.jpg
#   inflating: processed_combine_asl_dataset/y/Y1743.jpg
#   inflating: processed_combine_asl_dataset/y/Y1744.jpg
#   inflating: processed_combine_asl_dataset/y/Y1745.jpg
#   inflating: processed_combine_asl_dataset/y/Y1746.jpg
#   inflating: processed_combine_asl_dataset/y/Y1747.jpg
#   inflating: processed_combine_asl_dataset/y/Y1748.jpg
#   inflating: processed_combine_asl_dataset/y/Y1749.jpg
#   inflating: processed_combine_asl_dataset/y/Y175.jpg
#   inflating: processed_combine_asl_dataset/y/Y1750.jpg
#   inflating: processed_combine_asl_dataset/y/Y1751.jpg
#   inflating: processed_combine_asl_dataset/y/Y1752.jpg
#   inflating: processed_combine_asl_dataset/y/Y1753.jpg
#   inflating: processed_combine_asl_dataset/y/Y1754.jpg
#   inflating: processed_combine_asl_dataset/y/Y1755.jpg
#   inflating: processed_combine_asl_dataset/y/Y1756.jpg
#   inflating: processed_combine_asl_dataset/y/Y1757.jpg
#   inflating: processed_combine_asl_dataset/y/Y1758.jpg
#   inflating: processed_combine_asl_dataset/y/Y1759.jpg
#   inflating: processed_combine_asl_dataset/y/Y176.jpg
#   inflating: processed_combine_asl_dataset/y/Y1760.jpg
#   inflating: processed_combine_asl_dataset/y/Y1761.jpg
#   inflating: processed_combine_asl_dataset/y/Y1762.jpg
#   inflating: processed_combine_asl_dataset/y/Y1763.jpg
#   inflating: processed_combine_asl_dataset/y/Y1764.jpg
#   inflating: processed_combine_asl_dataset/y/Y1765.jpg
#   inflating: processed_combine_asl_dataset/y/Y1766.jpg
#   inflating: processed_combine_asl_dataset/y/Y1767.jpg
#   inflating: processed_combine_asl_dataset/y/Y177.jpg
#   inflating: processed_combine_asl_dataset/y/Y1770.jpg
#   inflating: processed_combine_asl_dataset/y/Y1771 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1771.jpg
#   inflating: processed_combine_asl_dataset/y/Y1772.jpg
#   inflating: processed_combine_asl_dataset/y/Y1773.jpg
#   inflating: processed_combine_asl_dataset/y/Y1774.jpg
#   inflating: processed_combine_asl_dataset/y/Y1775.jpg
#   inflating: processed_combine_asl_dataset/y/Y1776 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1776.jpg
#   inflating: processed_combine_asl_dataset/y/Y1777.jpg
#   inflating: processed_combine_asl_dataset/y/Y1778.jpg
#   inflating: processed_combine_asl_dataset/y/Y1779.jpg
#   inflating: processed_combine_asl_dataset/y/Y178.jpg
#   inflating: processed_combine_asl_dataset/y/Y1780.jpg
#   inflating: processed_combine_asl_dataset/y/Y1781 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1781.jpg
#   inflating: processed_combine_asl_dataset/y/Y1782.jpg
#   inflating: processed_combine_asl_dataset/y/Y1783.jpg
#   inflating: processed_combine_asl_dataset/y/Y1784 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1784.jpg
#   inflating: processed_combine_asl_dataset/y/Y1785.jpg
#   inflating: processed_combine_asl_dataset/y/Y1786 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1786.jpg
#   inflating: processed_combine_asl_dataset/y/Y1787.jpg
#   inflating: processed_combine_asl_dataset/y/Y1788.jpg
#   inflating: processed_combine_asl_dataset/y/Y1789.jpg
#   inflating: processed_combine_asl_dataset/y/Y179.jpg
#   inflating: processed_combine_asl_dataset/y/Y1790 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1790.jpg
#   inflating: processed_combine_asl_dataset/y/Y1791.jpg
#   inflating: processed_combine_asl_dataset/y/Y1792.jpg
#   inflating: processed_combine_asl_dataset/y/Y1793.jpg
#   inflating: processed_combine_asl_dataset/y/Y1794.jpg
#   inflating: processed_combine_asl_dataset/y/Y1795.jpg
#   inflating: processed_combine_asl_dataset/y/Y1796 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1796.jpg
#   inflating: processed_combine_asl_dataset/y/Y1797.jpg
#   inflating: processed_combine_asl_dataset/y/Y1798 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1798.jpg
#   inflating: processed_combine_asl_dataset/y/Y1799.jpg
#   inflating: processed_combine_asl_dataset/y/Y18.jpg
#   inflating: processed_combine_asl_dataset/y/Y180.jpg
#   inflating: processed_combine_asl_dataset/y/Y1800 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1800.jpg
#   inflating: processed_combine_asl_dataset/y/Y1801.jpg
#   inflating: processed_combine_asl_dataset/y/Y1802.jpg
#   inflating: processed_combine_asl_dataset/y/Y1803.jpg
#   inflating: processed_combine_asl_dataset/y/Y1804.jpg
#   inflating: processed_combine_asl_dataset/y/Y1805.jpg
#   inflating: processed_combine_asl_dataset/y/Y1806 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1806.jpg
#   inflating: processed_combine_asl_dataset/y/Y1807.jpg
#   inflating: processed_combine_asl_dataset/y/Y1808 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1808.jpg
#   inflating: processed_combine_asl_dataset/y/Y1809.jpg
#   inflating: processed_combine_asl_dataset/y/Y181.jpg
#   inflating: processed_combine_asl_dataset/y/Y1810.jpg
#   inflating: processed_combine_asl_dataset/y/Y1811.jpg
#   inflating: processed_combine_asl_dataset/y/Y1812.jpg
#   inflating: processed_combine_asl_dataset/y/Y1815.jpg
#   inflating: processed_combine_asl_dataset/y/Y1816.jpg
#   inflating: processed_combine_asl_dataset/y/Y1817.jpg
#   inflating: processed_combine_asl_dataset/y/Y1818.jpg
#   inflating: processed_combine_asl_dataset/y/Y1819.jpg
#   inflating: processed_combine_asl_dataset/y/Y182.jpg
#   inflating: processed_combine_asl_dataset/y/Y1820 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1820.jpg
#   inflating: processed_combine_asl_dataset/y/Y1821.jpg
#   inflating: processed_combine_asl_dataset/y/Y1822.jpg
#   inflating: processed_combine_asl_dataset/y/Y1823.jpg
#   inflating: processed_combine_asl_dataset/y/Y1824.jpg
#   inflating: processed_combine_asl_dataset/y/Y1825.jpg
#   inflating: processed_combine_asl_dataset/y/Y1826.jpg
#   inflating: processed_combine_asl_dataset/y/Y1827.jpg
#   inflating: processed_combine_asl_dataset/y/Y1828.jpg
#   inflating: processed_combine_asl_dataset/y/Y1829.jpg
#   inflating: processed_combine_asl_dataset/y/Y183.jpg
#   inflating: processed_combine_asl_dataset/y/Y1830.jpg
#   inflating: processed_combine_asl_dataset/y/Y1831.jpg
#   inflating: processed_combine_asl_dataset/y/Y1832.jpg
#   inflating: processed_combine_asl_dataset/y/Y1833.jpg
#   inflating: processed_combine_asl_dataset/y/Y1834.jpg
#   inflating: processed_combine_asl_dataset/y/Y1835.jpg
#   inflating: processed_combine_asl_dataset/y/Y1836 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1836.jpg
#   inflating: processed_combine_asl_dataset/y/Y1837.jpg
#   inflating: processed_combine_asl_dataset/y/Y1838.jpg
#   inflating: processed_combine_asl_dataset/y/Y1839.jpg
#   inflating: processed_combine_asl_dataset/y/Y184.jpg
#   inflating: processed_combine_asl_dataset/y/Y1840.jpg
#   inflating: processed_combine_asl_dataset/y/Y1841 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1841.jpg
#   inflating: processed_combine_asl_dataset/y/Y1842.jpg
#   inflating: processed_combine_asl_dataset/y/Y1843.jpg
#   inflating: processed_combine_asl_dataset/y/Y1844.jpg
#   inflating: processed_combine_asl_dataset/y/Y1845.jpg
#   inflating: processed_combine_asl_dataset/y/Y1846.jpg
#   inflating: processed_combine_asl_dataset/y/Y1847.jpg
#   inflating: processed_combine_asl_dataset/y/Y1848.jpg
#   inflating: processed_combine_asl_dataset/y/Y1849.jpg
#   inflating: processed_combine_asl_dataset/y/Y185.jpg
#   inflating: processed_combine_asl_dataset/y/Y1850.jpg
#   inflating: processed_combine_asl_dataset/y/Y1851 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1851.jpg
#   inflating: processed_combine_asl_dataset/y/Y1852.jpg
#   inflating: processed_combine_asl_dataset/y/Y1853.jpg
#   inflating: processed_combine_asl_dataset/y/Y1854.jpg
#   inflating: processed_combine_asl_dataset/y/Y1855.jpg
#   inflating: processed_combine_asl_dataset/y/Y1856.jpg
#   inflating: processed_combine_asl_dataset/y/Y1857.jpg
#   inflating: processed_combine_asl_dataset/y/Y1858.jpg
#   inflating: processed_combine_asl_dataset/y/Y1859.jpg
#   inflating: processed_combine_asl_dataset/y/Y186.jpg
#   inflating: processed_combine_asl_dataset/y/Y1860.jpg
#   inflating: processed_combine_asl_dataset/y/Y1861.jpg
#   inflating: processed_combine_asl_dataset/y/Y1862.jpg
#   inflating: processed_combine_asl_dataset/y/Y1863.jpg
#   inflating: processed_combine_asl_dataset/y/Y1864.jpg
#   inflating: processed_combine_asl_dataset/y/Y1865.jpg
#   inflating: processed_combine_asl_dataset/y/Y1866.jpg
#   inflating: processed_combine_asl_dataset/y/Y1867.jpg
#   inflating: processed_combine_asl_dataset/y/Y1868.jpg
#   inflating: processed_combine_asl_dataset/y/Y1869.jpg
#   inflating: processed_combine_asl_dataset/y/Y187.jpg
#   inflating: processed_combine_asl_dataset/y/Y1870.jpg
#   inflating: processed_combine_asl_dataset/y/Y1871.jpg
#   inflating: processed_combine_asl_dataset/y/Y1872.jpg
#   inflating: processed_combine_asl_dataset/y/Y1873.jpg
#   inflating: processed_combine_asl_dataset/y/Y1874.jpg
#   inflating: processed_combine_asl_dataset/y/Y1875.jpg
#   inflating: processed_combine_asl_dataset/y/Y1876.jpg
#   inflating: processed_combine_asl_dataset/y/Y1877.jpg
#   inflating: processed_combine_asl_dataset/y/Y1878.jpg
#   inflating: processed_combine_asl_dataset/y/Y1879.jpg
#   inflating: processed_combine_asl_dataset/y/Y188.jpg
#   inflating: processed_combine_asl_dataset/y/Y1880.jpg
#   inflating: processed_combine_asl_dataset/y/Y1881.jpg
#   inflating: processed_combine_asl_dataset/y/Y1882.jpg
#   inflating: processed_combine_asl_dataset/y/Y1883.jpg
#   inflating: processed_combine_asl_dataset/y/Y1884 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1884.jpg
#   inflating: processed_combine_asl_dataset/y/Y1885.jpg
#   inflating: processed_combine_asl_dataset/y/Y1886.jpg
#   inflating: processed_combine_asl_dataset/y/Y1887.jpg
#   inflating: processed_combine_asl_dataset/y/Y1888.jpg
#   inflating: processed_combine_asl_dataset/y/Y1889.jpg
#   inflating: processed_combine_asl_dataset/y/Y189.jpg
#   inflating: processed_combine_asl_dataset/y/Y1890 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1890.jpg
#   inflating: processed_combine_asl_dataset/y/Y1891.jpg
#   inflating: processed_combine_asl_dataset/y/Y1892.jpg
#   inflating: processed_combine_asl_dataset/y/Y1893.jpg
#   inflating: processed_combine_asl_dataset/y/Y1894.jpg
#   inflating: processed_combine_asl_dataset/y/Y1895.jpg
#   inflating: processed_combine_asl_dataset/y/Y1896.jpg
#   inflating: processed_combine_asl_dataset/y/Y1897.jpg
#   inflating: processed_combine_asl_dataset/y/Y1898 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1898.jpg
#   inflating: processed_combine_asl_dataset/y/Y1899.jpg
#   inflating: processed_combine_asl_dataset/y/Y19 - Copy - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y19.jpg
#   inflating: processed_combine_asl_dataset/y/Y190.jpg
#   inflating: processed_combine_asl_dataset/y/Y1900.jpg
#   inflating: processed_combine_asl_dataset/y/Y1901.jpg
#   inflating: processed_combine_asl_dataset/y/Y1902.jpg
#   inflating: processed_combine_asl_dataset/y/Y1903.jpg
#   inflating: processed_combine_asl_dataset/y/Y1904 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1904.jpg
#   inflating: processed_combine_asl_dataset/y/Y1905.jpg
#   inflating: processed_combine_asl_dataset/y/Y1906.jpg
#   inflating: processed_combine_asl_dataset/y/Y1907.jpg
#   inflating: processed_combine_asl_dataset/y/Y1908.jpg
#   inflating: processed_combine_asl_dataset/y/Y1909.jpg
#   inflating: processed_combine_asl_dataset/y/Y191.jpg
#   inflating: processed_combine_asl_dataset/y/Y1910.jpg
#   inflating: processed_combine_asl_dataset/y/Y1911.jpg
#   inflating: processed_combine_asl_dataset/y/Y1912 - Copy.jpg
#   inflating: processed_combine_asl_dataset/y/Y1912.jpg
#   inflating: processed_combine_asl_dataset/y/Y1913.jpg
#   inflating: processed_combine_asl_dataset/y/Y1914.jpg
#   inflating: processed_combine_asl_dataset/y/Y1915.jpg
#   inflating: processed_combine_asl_dataset/y/Y1916.jpg
# ...
#   inflating: processed_combine_asl_dataset/z/Z74.jpg
#   inflating: processed_combine_asl_dataset/z/Z740.jpg
#   inflating: processed_combine_asl_dataset/z/Z741.jpg
#   inflating: processed_combine_asl_dataset/z/Z742.jpg
#   inflating: processed_combine_asl_dataset/z/Z743.jpg
#   inflating: processed_combine_asl_dataset/z/Z744.jpg
#   inflating: processed_combine_asl_dataset/z/Z745.jpg
#   inflating: processed_combine_asl_dataset/z/Z746.jpg
#   inflating: processed_combine_asl_dataset/z/Z747.jpg
#   inflating: processed_combine_asl_dataset/z/Z748.jpg
#   inflating: processed_combine_asl_dataset/z/Z749.jpg
#   inflating: processed_combine_asl_dataset/z/Z75.jpg
#   inflating: processed_combine_asl_dataset/z/Z750.jpg
#   inflating: processed_combine_asl_dataset/z/Z751.jpg
#   inflating: processed_combine_asl_dataset/z/Z752.jpg
#   inflating: processed_combine_asl_dataset/z/Z753.jpg
#   inflating: processed_combine_asl_dataset/z/Z754.jpg
#   inflating: processed_combine_asl_dataset/z/Z755.jpg
#   inflating: processed_combine_asl_dataset/z/Z756.jpg
#   inflating: processed_combine_asl_dataset/z/Z757.jpg
#   inflating: processed_combine_asl_dataset/z/Z758.jpg
#   inflating: processed_combine_asl_dataset/z/Z759.jpg
#   inflating: processed_combine_asl_dataset/z/Z76.jpg
#   inflating: processed_combine_asl_dataset/z/Z760.jpg
#   inflating: processed_combine_asl_dataset/z/Z761.jpg
#   inflating: processed_combine_asl_dataset/z/Z762.jpg
#   inflating: processed_combine_asl_dataset/z/Z763.jpg
#   inflating: processed_combine_asl_dataset/z/Z764.jpg
#   inflating: processed_combine_asl_dataset/z/Z765.jpg
#   inflating: processed_combine_asl_dataset/z/Z766.jpg
#   inflating: processed_combine_asl_dataset/z/Z767.jpg
#   inflating: processed_combine_asl_dataset/z/Z768.jpg
#   inflating: processed_combine_asl_dataset/z/Z769.jpg
#   inflating: processed_combine_asl_dataset/z/Z77.jpg
#   inflating: processed_combine_asl_dataset/z/Z770.jpg
#   inflating: processed_combine_asl_dataset/z/Z771.jpg
#   inflating: processed_combine_asl_dataset/z/Z772.jpg
#   inflating: processed_combine_asl_dataset/z/Z773.jpg
#   inflating: processed_combine_asl_dataset/z/Z774.jpg
#   inflating: processed_combine_asl_dataset/z/Z775.jpg
#   inflating: processed_combine_asl_dataset/z/Z776.jpg
#   inflating: processed_combine_asl_dataset/z/Z777.jpg
#   inflating: processed_combine_asl_dataset/z/Z778.jpg
#   inflating: processed_combine_asl_dataset/z/Z779.jpg
#   inflating: processed_combine_asl_dataset/z/Z78.jpg
#   inflating: processed_combine_asl_dataset/z/Z780.jpg
#   inflating: processed_combine_asl_dataset/z/Z781.jpg
#   inflating: processed_combine_asl_dataset/z/Z782.jpg
#   inflating: processed_combine_asl_dataset/z/Z783.jpg
#   inflating: processed_combine_asl_dataset/z/Z784.jpg
#   inflating: processed_combine_asl_dataset/z/Z785.jpg
#   inflating: processed_combine_asl_dataset/z/Z786.jpg
#   inflating: processed_combine_asl_dataset/z/Z787.jpg
#   inflating: processed_combine_asl_dataset/z/Z788.jpg
#   inflating: processed_combine_asl_dataset/z/Z789.jpg
#   inflating: processed_combine_asl_dataset/z/Z79.jpg
#   inflating: processed_combine_asl_dataset/z/Z790.jpg
#   inflating: processed_combine_asl_dataset/z/Z791.jpg
#   inflating: processed_combine_asl_dataset/z/Z792.jpg
#   inflating: processed_combine_asl_dataset/z/Z793.jpg
#   inflating: processed_combine_asl_dataset/z/Z794.jpg
#   inflating: processed_combine_asl_dataset/z/Z795.jpg
#   inflating: processed_combine_asl_dataset/z/Z796.jpg
#   inflating: processed_combine_asl_dataset/z/Z797.jpg
#   inflating: processed_combine_asl_dataset/z/Z798.jpg
#   inflating: processed_combine_asl_dataset/z/Z799.jpg
#   inflating: processed_combine_asl_dataset/z/Z80.jpg
#   inflating: processed_combine_asl_dataset/z/Z800.jpg
#   inflating: processed_combine_asl_dataset/z/Z801.jpg
#   inflating: processed_combine_asl_dataset/z/Z802.jpg
#   inflating: processed_combine_asl_dataset/z/Z803.jpg
#   inflating: processed_combine_asl_dataset/z/Z804.jpg
#   inflating: processed_combine_asl_dataset/z/Z805.jpg
#   inflating: processed_combine_asl_dataset/z/Z806.jpg
#   inflating: processed_combine_asl_dataset/z/Z807.jpg
#   inflating: processed_combine_asl_dataset/z/Z808.jpg
#   inflating: processed_combine_asl_dataset/z/Z809.jpg
#   inflating: processed_combine_asl_dataset/z/Z81.jpg
#   inflating: processed_combine_asl_dataset/z/Z810.jpg
#   inflating: processed_combine_asl_dataset/z/Z811.jpg
#   inflating: processed_combine_asl_dataset/z/Z812.jpg
#   inflating: processed_combine_asl_dataset/z/Z813.jpg
#   inflating: processed_combine_asl_dataset/z/Z814.jpg
#   inflating: processed_combine_asl_dataset/z/Z815.jpg
#   inflating: processed_combine_asl_dataset/z/Z816.jpg
#   inflating: processed_combine_asl_dataset/z/Z817.jpg
#   inflating: processed_combine_asl_dataset/z/Z818.jpg
#   inflating: processed_combine_asl_dataset/z/Z819.jpg
#   inflating: processed_combine_asl_dataset/z/Z82.jpg
#   inflating: processed_combine_asl_dataset/z/Z820.jpg
#   inflating: processed_combine_asl_dataset/z/Z821.jpg
#   inflating: processed_combine_asl_dataset/z/Z822.jpg
#   inflating: processed_combine_asl_dataset/z/Z823.jpg
#   inflating: processed_combine_asl_dataset/z/Z824.jpg
#   inflating: processed_combine_asl_dataset/z/Z825.jpg
#   inflating: processed_combine_asl_dataset/z/Z826.jpg
#   inflating: processed_combine_asl_dataset/z/Z827.jpg
#   inflating: processed_combine_asl_dataset/z/Z828.jpg
#   inflating: processed_combine_asl_dataset/z/Z829.jpg
#   inflating: processed_combine_asl_dataset/z/Z83.jpg
#   inflating: processed_combine_asl_dataset/z/Z830.jpg
#   inflating: processed_combine_asl_dataset/z/Z831.jpg
#   inflating: processed_combine_asl_dataset/z/Z832.jpg
#   inflating: processed_combine_asl_dataset/z/Z833.jpg
#   inflating: processed_combine_asl_dataset/z/Z834.jpg
#   inflating: processed_combine_asl_dataset/z/Z835.jpg
#   inflating: processed_combine_asl_dataset/z/Z836.jpg
#   inflating: processed_combine_asl_dataset/z/Z837.jpg
#   inflating: processed_combine_asl_dataset/z/Z838.jpg
#   inflating: processed_combine_asl_dataset/z/Z839.jpg
#   inflating: processed_combine_asl_dataset/z/Z84.jpg
#   inflating: processed_combine_asl_dataset/z/Z840.jpg
#   inflating: processed_combine_asl_dataset/z/Z841.jpg
#   inflating: processed_combine_asl_dataset/z/Z842.jpg
#   inflating: processed_combine_asl_dataset/z/Z843.jpg
#   inflating: processed_combine_asl_dataset/z/Z844.jpg
#   inflating: processed_combine_asl_dataset/z/Z845.jpg
#   inflating: processed_combine_asl_dataset/z/Z846.jpg
#   inflating: processed_combine_asl_dataset/z/Z847.jpg
#   inflating: processed_combine_asl_dataset/z/Z848.jpg
#   inflating: processed_combine_asl_dataset/z/Z849.jpg
#   inflating: processed_combine_asl_dataset/z/Z85.jpg
#   inflating: processed_combine_asl_dataset/z/Z850.jpg
#   inflating: processed_combine_asl_dataset/z/Z851.jpg
#   inflating: processed_combine_asl_dataset/z/Z852.jpg
#   inflating: processed_combine_asl_dataset/z/Z853.jpg
#   inflating: processed_combine_asl_dataset/z/Z854.jpg
#   inflating: processed_combine_asl_dataset/z/Z855.jpg
#   inflating: processed_combine_asl_dataset/z/Z856.jpg
#   inflating: processed_combine_asl_dataset/z/Z857.jpg
#   inflating: processed_combine_asl_dataset/z/Z858.jpg
#   inflating: processed_combine_asl_dataset/z/Z859.jpg
#   inflating: processed_combine_asl_dataset/z/Z86.jpg
#   inflating: processed_combine_asl_dataset/z/Z860.jpg
#   inflating: processed_combine_asl_dataset/z/Z861.jpg
#   inflating: processed_combine_asl_dataset/z/Z862.jpg
#   inflating: processed_combine_asl_dataset/z/Z863.jpg
#   inflating: processed_combine_asl_dataset/z/Z864.jpg
#   inflating: processed_combine_asl_dataset/z/Z865.jpg
#   inflating: processed_combine_asl_dataset/z/Z866.jpg
#   inflating: processed_combine_asl_dataset/z/Z867.jpg
#   inflating: processed_combine_asl_dataset/z/Z868.jpg
#   inflating: processed_combine_asl_dataset/z/Z869.jpg
#   inflating: processed_combine_asl_dataset/z/Z87.jpg
#   inflating: processed_combine_asl_dataset/z/Z870.jpg
#   inflating: processed_combine_asl_dataset/z/Z871.jpg
#   inflating: processed_combine_asl_dataset/z/Z872.jpg
#   inflating: processed_combine_asl_dataset/z/Z873.jpg
#   inflating: processed_combine_asl_dataset/z/Z874.jpg
#   inflating: processed_combine_asl_dataset/z/Z875.jpg
#   inflating: processed_combine_asl_dataset/z/Z876.jpg
#   inflating: processed_combine_asl_dataset/z/Z877.jpg
#   inflating: processed_combine_asl_dataset/z/Z878.jpg
#   inflating: processed_combine_asl_dataset/z/Z879.jpg
#   inflating: processed_combine_asl_dataset/z/Z88.jpg
#   inflating: processed_combine_asl_dataset/z/Z880.jpg
#   inflating: processed_combine_asl_dataset/z/Z881.jpg
#   inflating: processed_combine_asl_dataset/z/Z882.jpg
#   inflating: processed_combine_asl_dataset/z/Z883.jpg
#   inflating: processed_combine_asl_dataset/z/Z884.jpg
#   inflating: processed_combine_asl_dataset/z/Z885.jpg
#   inflating: processed_combine_asl_dataset/z/Z886.jpg
#   inflating: processed_combine_asl_dataset/z/Z887.jpg
#   inflating: processed_combine_asl_dataset/z/Z888.jpg
#   inflating: processed_combine_asl_dataset/z/Z889.jpg
#   inflating: processed_combine_asl_dataset/z/Z89.jpg
#   inflating: processed_combine_asl_dataset/z/Z890.jpg
#   inflating: processed_combine_asl_dataset/z/Z891.jpg
#   inflating: processed_combine_asl_dataset/z/Z892.jpg
#   inflating: processed_combine_asl_dataset/z/Z893.jpg
#   inflating: processed_combine_asl_dataset/z/Z894.jpg
#   inflating: processed_combine_asl_dataset/z/Z895.jpg
#   inflating: processed_combine_asl_dataset/z/Z896.jpg
#   inflating: processed_combine_asl_dataset/z/Z897.jpg
#   inflating: processed_combine_asl_dataset/z/Z898.jpg
#   inflating: processed_combine_asl_dataset/z/Z899.jpg
#   inflating: processed_combine_asl_dataset/z/Z90.jpg
#   inflating: processed_combine_asl_dataset/z/Z900.jpg
#   inflating: processed_combine_asl_dataset/z/Z901.jpg
#   inflating: processed_combine_asl_dataset/z/Z902.jpg
#   inflating: processed_combine_asl_dataset/z/Z903.jpg
#   inflating: processed_combine_asl_dataset/z/Z904.jpg
#   inflating: processed_combine_asl_dataset/z/Z905.jpg
#   inflating: processed_combine_asl_dataset/z/Z906.jpg
#   inflating: processed_combine_asl_dataset/z/Z907.jpg
#   inflating: processed_combine_asl_dataset/z/Z908.jpg
#   inflating: processed_combine_asl_dataset/z/Z909.jpg
#   inflating: processed_combine_asl_dataset/z/Z91.jpg
#   inflating: processed_combine_asl_dataset/z/Z910.jpg
#   inflating: processed_combine_asl_dataset/z/Z911.jpg
#   inflating: processed_combine_asl_dataset/z/Z912.jpg
#   inflating: processed_combine_asl_dataset/z/Z913.jpg
#   inflating: processed_combine_asl_dataset/z/Z914.jpg
#   inflating: processed_combine_asl_dataset/z/Z915.jpg
#   inflating: processed_combine_asl_dataset/z/Z916.jpg
#   inflating: processed_combine_asl_dataset/z/Z917.jpg
#   inflating: processed_combine_asl_dataset/z/Z918.jpg
#   inflating: processed_combine_asl_dataset/z/Z919.jpg
#   inflating: processed_combine_asl_dataset/z/Z92.jpg
#   inflating: processed_combine_asl_dataset/z/Z920.jpg
#   inflating: processed_combine_asl_dataset/z/Z921.jpg
#   inflating: processed_combine_asl_dataset/z/Z922.jpg
#   inflating: processed_combine_asl_dataset/z/Z923.jpg
#   inflating: processed_combine_asl_dataset/z/Z924.jpg
#   inflating: processed_combine_asl_dataset/z/Z925.jpg
#   inflating: processed_combine_asl_dataset/z/Z926.jpg
#   inflating: processed_combine_asl_dataset/z/Z927.jpg
#   inflating: processed_combine_asl_dataset/z/Z928.jpg
#   inflating: processed_combine_asl_dataset/z/Z929.jpg
#   inflating: processed_combine_asl_dataset/z/Z93.jpg
#   inflating: processed_combine_asl_dataset/z/Z930.jpg
#   inflating: processed_combine_asl_dataset/z/Z931.jpg
#   inflating: processed_combine_asl_dataset/z/Z932.jpg
#   inflating: processed_combine_asl_dataset/z/Z933.jpg
#   inflating: processed_combine_asl_dataset/z/Z934.jpg
#   inflating: processed_combine_asl_dataset/z/Z935.jpg
#   inflating: processed_combine_asl_dataset/z/Z936.jpg
#   inflating: processed_combine_asl_dataset/z/Z937.jpg
#   inflating: processed_combine_asl_dataset/z/Z938.jpg
#   inflating: processed_combine_asl_dataset/z/Z939.jpg
#   inflating: processed_combine_asl_dataset/z/Z94.jpg
#   inflating: processed_combine_asl_dataset/z/Z940.jpg
#   inflating: processed_combine_asl_dataset/z/Z941.jpg
#   inflating: processed_combine_asl_dataset/z/Z942.jpg
#   inflating: processed_combine_asl_dataset/z/Z943.jpg
#   inflating: processed_combine_asl_dataset/z/Z944.jpg
#   inflating: processed_combine_asl_dataset/z/Z945.jpg
#   inflating: processed_combine_asl_dataset/z/Z946.jpg
#   inflating: processed_combine_asl_dataset/z/Z947.jpg
#   inflating: processed_combine_asl_dataset/z/Z948.jpg
#   inflating: processed_combine_asl_dataset/z/Z949.jpg
#   inflating: processed_combine_asl_dataset/z/Z95.jpg
#   inflating: processed_combine_asl_dataset/z/Z950.jpg
#   inflating: processed_combine_asl_dataset/z/Z951.jpg
#   inflating: processed_combine_asl_dataset/z/Z952.jpg
#   inflating: processed_combine_asl_dataset/z/Z953.jpg
#   inflating: processed_combine_asl_dataset/z/Z954.jpg
#   inflating: processed_combine_asl_dataset/z/Z955.jpg
#   inflating: processed_combine_asl_dataset/z/Z956.jpg
#   inflating: processed_combine_asl_dataset/z/Z957.jpg
#   inflating: processed_combine_asl_dataset/z/Z958.jpg
#   inflating: processed_combine_asl_dataset/z/Z959.jpg
#   inflating: processed_combine_asl_dataset/z/Z96.jpg
#   inflating: processed_combine_asl_dataset/z/Z960.jpg
#   inflating: processed_combine_asl_dataset/z/Z961.jpg
#   inflating: processed_combine_asl_dataset/z/Z962.jpg
#   inflating: processed_combine_asl_dataset/z/Z963.jpg
#   inflating: processed_combine_asl_dataset/z/Z964.jpg
#   inflating: processed_combine_asl_dataset/z/Z965.jpg
#   inflating: processed_combine_asl_dataset/z/Z966.jpg
#   inflating: processed_combine_asl_dataset/z/Z967.jpg
#   inflating: processed_combine_asl_dataset/z/Z968.jpg
#   inflating: processed_combine_asl_dataset/z/Z969.jpg
#   inflating: processed_combine_asl_dataset/z/Z97.jpg
#   inflating: processed_combine_asl_dataset/z/Z970.jpg
#   inflating: processed_combine_asl_dataset/z/Z971.jpg
#   inflating: processed_combine_asl_dataset/z/Z972.jpg
#   inflating: processed_combine_asl_dataset/z/Z973.jpg
#   inflating: processed_combine_asl_dataset/z/Z974.jpg
#   inflating: processed_combine_asl_dataset/z/Z975.jpg
#   inflating: processed_combine_asl_dataset/z/Z976.jpg
#   inflating: processed_combine_asl_dataset/z/Z977.jpg
#   inflating: processed_combine_asl_dataset/z/Z978.jpg
#   inflating: processed_combine_asl_dataset/z/Z979.jpg
#   inflating: processed_combine_asl_dataset/z/Z98.jpg
#   inflating: processed_combine_asl_dataset/z/Z980.jpg
#   inflating: processed_combine_asl_dataset/z/Z981.jpg
#   inflating: processed_combine_asl_dataset/z/Z982.jpg
#   inflating: processed_combine_asl_dataset/z/Z983.jpg
#   inflating: processed_combine_asl_dataset/z/Z984.jpg
#   inflating: processed_combine_asl_dataset/z/Z985.jpg
#   inflating: processed_combine_asl_dataset/z/Z986.jpg
#   inflating: processed_combine_asl_dataset/z/Z987.jpg
#   inflating: processed_combine_asl_dataset/z/Z988.jpg
#   inflating: processed_combine_asl_dataset/z/Z989.jpg
#   inflating: processed_combine_asl_dataset/z/Z99.jpg
#   inflating: processed_combine_asl_dataset/z/Z990.jpg
#   inflating: processed_combine_asl_dataset/z/Z991.jpg
#   inflating: processed_combine_asl_dataset/z/Z992.jpg
#   inflating: processed_combine_asl_dataset/z/Z993.jpg
#   inflating: processed_combine_asl_dataset/z/Z994.jpg
#   inflating: processed_combine_asl_dataset/z/Z995.jpg
#   inflating: processed_combine_asl_dataset/z/Z996.jpg
#   inflating: processed_combine_asl_dataset/z/Z997.jpg
#   inflating: processed_combine_asl_dataset/z/Z998.jpg
#   inflating: processed_combine_asl_dataset/z/Z999.jpg

# %%
import os
import csv

directory = "./processed_combine_asl_dataset"
ext = [".png", ".jpg", ".jpeg"]

with open('mp-to-asl.csv', newline='', mode='w+') as data:
    writer = csv.writer(data, quotechar='"', quoting=csv.QUOTE_ALL)
    writer.writerow(["image_path", "label"])
    for path, folders, files in os.walk(directory):
        for file in files:
            writer.writerow([
                os.path.join(path, file),
                path.split('/')[-1].upper()
            ])

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.preprocessing import LabelEncoder

batch_size = 128
train_generator = DataGenerator(csv_file='mp-to-asl.csv', batch_size=batch_size)
val_generator = DataGenerator(csv_file='mp-to-asl.csv', batch_size=batch_size, shuffle=False)

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(400, 400, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(36, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

with tf.device('/gpu:0'):
  model.fit(train_generator, validation_data=val_generator, epochs=15)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 490s 569ms/step - accuracy: 0.6348 - loss: 1.3081 - val_accuracy: 0.9684 - val_loss: 0.1320
# Epoch 2/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 462s 559ms/step - accuracy: 0.9730 - loss: 0.0976 - val_accuracy: 0.9911 - val_loss: 0.0350
# Epoch 3/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 463s 561ms/step - accuracy: 0.9895 - loss: 0.0341 - val_accuracy: 0.9916 - val_loss: 0.0279
# Epoch 4/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 463s 561ms/step - accuracy: 0.9909 - loss: 0.0270 - val_accuracy: 0.9947 - val_loss: 0.0179
# Epoch 5/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 463s 560ms/step - accuracy: 0.9939 - loss: 0.0196 - val_accuracy: 0.9935 - val_loss: 0.0208
# Epoch 6/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 461s 558ms/step - accuracy: 0.9951 - loss: 0.0176 - val_accuracy: 0.9955 - val_loss: 0.0138
# Epoch 7/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 462s 560ms/step - accuracy: 0.9960 - loss: 0.0126 - val_accuracy: 0.9963 - val_loss: 0.0119
# Epoch 8/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 462s 559ms/step - accuracy: 0.9955 - loss: 0.0140 - val_accuracy: 0.9975 - val_loss: 0.0082
# Epoch 9/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 461s 559ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.9974 - val_loss: 0.0085
# Epoch 10/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 463s 561ms/step - accuracy: 0.9970 - loss: 0.0094 - val_accuracy: 0.9985 - val_loss: 0.0049
# Epoch 11/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 466s 563ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9969 - val_loss: 0.0115
# Epoch 12/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 463s 561ms/step - accuracy: 0.9973 - loss: 0.0086 - val_accuracy: 0.9984 - val_loss: 0.0055
# Epoch 13/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 463s 561ms/step - accuracy: 0.9978 - loss: 0.0078 - val_accuracy: 0.9970 - val_loss: 0.0094
# Epoch 14/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 464s 561ms/step - accuracy: 0.9977 - loss: 0.0071 - val_accuracy: 0.9989 - val_loss: 0.0042
# Epoch 15/15
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 463s 561ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 0.9988 - val_loss: 0.0042

# %%
model.save('mp-to-asl-cnn-model.keras')

# %%
model.save('mp-to-asl-cnn-model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
