# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

data = pd.read_csv("mp-landmarks-to-asl.csv")

X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=0.3, random_state=42, stratify=y_encoded)

model = Sequential([
    Dense(128, input_shape=(63,), activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(26, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

with tf.device('/gpu:0'):
  history = model.fit(
      X_train, y_train,
      epochs=300, batch_size=256,
      validation_data=(X_val, y_val),
      callbacks=[early_stopping])

model.save("mp-landmarks-to-asl-nn.keras")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.7392 - loss: 0.8743 - val_accuracy: 0.9223 - val_loss: 0.2007
# Epoch 2/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9609 - loss: 0.1038 - val_accuracy: 0.9859 - val_loss: 0.0433
# Epoch 3/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9845 - loss: 0.0446 - val_accuracy: 0.9873 - val_loss: 0.0349
# Epoch 4/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9906 - loss: 0.0278 - val_accuracy: 0.9953 - val_loss: 0.0146
# Epoch 5/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9925 - loss: 0.0215 - val_accuracy: 0.9967 - val_loss: 0.0106
# Epoch 6/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0170 - val_accuracy: 0.9955 - val_loss: 0.0132
# Epoch 7/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9954 - loss: 0.0134 - val_accuracy: 0.9971 - val_loss: 0.0081
# Epoch 8/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9947 - loss: 0.0149 - val_accuracy: 0.9941 - val_loss: 0.0172
# Epoch 9/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9947 - loss: 0.0153 - val_accuracy: 0.9979 - val_loss: 0.0061
# Epoch 10/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9954 - loss: 0.0135 - val_accuracy: 0.9986 - val_loss: 0.0043
# Epoch 11/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9962 - loss: 0.0109 - val_accuracy: 0.9954 - val_loss: 0.0122
# Epoch 12/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0086 - val_accuracy: 0.9984 - val_loss: 0.0048
# Epoch 13/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0080 - val_accuracy: 0.9988 - val_loss: 0.0039
# Epoch 14/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0090 - val_accuracy: 0.9974 - val_loss: 0.0107
# Epoch 15/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.9893 - val_loss: 0.0345
# Epoch 16/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0091 - val_accuracy: 0.9986 - val_loss: 0.0040
# Epoch 17/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 0.9983 - val_loss: 0.0049
# Epoch 18/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9979 - loss: 0.0060 - val_accuracy: 0.9982 - val_loss: 0.0051
# Epoch 19/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.9946 - val_loss: 0.0155
# Epoch 20/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9978 - loss: 0.0061 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 21/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9982 - loss: 0.0053 - val_accuracy: 0.9973 - val_loss: 0.0076
# Epoch 22/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9981 - loss: 0.0061 - val_accuracy: 0.9993 - val_loss: 0.0019
# Epoch 23/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0037 - val_accuracy: 0.9986 - val_loss: 0.0039
# Epoch 24/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9989 - loss: 0.0033 - val_accuracy: 0.9995 - val_loss: 0.0016
# Epoch 25/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9998 - val_loss: 9.9822e-04
# Epoch 26/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9967 - val_loss: 0.0090
# Epoch 27/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0046 - val_accuracy: 0.9993 - val_loss: 0.0019
# Epoch 28/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0043 - val_accuracy: 0.9951 - val_loss: 0.0139
# Epoch 29/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9982 - loss: 0.0052 - val_accuracy: 0.9982 - val_loss: 0.0057
# Epoch 30/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 0.9993 - val_loss: 0.0016
# Epoch 31/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0037 - val_accuracy: 0.9990 - val_loss: 0.0031
# Epoch 32/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9995 - val_loss: 0.0016
# Epoch 33/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9997 - val_loss: 0.0011
# Epoch 34/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9998 - val_loss: 6.4738e-04
# Epoch 35/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9993 - loss: 0.0025 - val_accuracy: 0.9982 - val_loss: 0.0069
# Epoch 36/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 0.9971 - val_loss: 0.0103
# Epoch 37/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0047 - val_accuracy: 0.9989 - val_loss: 0.0031
# Epoch 38/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0034 - val_accuracy: 0.9993 - val_loss: 0.0022
# Epoch 39/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9993 - val_loss: 0.0023
# Epoch 40/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9989 - loss: 0.0036 - val_accuracy: 0.9923 - val_loss: 0.0275
# Epoch 41/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9983 - loss: 0.0055 - val_accuracy: 0.9986 - val_loss: 0.0047
# Epoch 42/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9989 - loss: 0.0033 - val_accuracy: 0.9996 - val_loss: 0.0012
# Epoch 43/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9975 - val_loss: 0.0070
# Epoch 44/300
# 1151/1151 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9987 - val_loss: 0.0044

# %%
np.save("landmark_label_classes.npy", label_encoder.classes_)
